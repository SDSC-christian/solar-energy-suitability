# %% [markdown]
# # Prepare images for annotation

# %%
import os

import numpy as np

import pandas as pd
import geopandas as gpd

from PIL import Image

from tqdm import tqdm

# %%
# Silence Pillow, as we do expect 100000000 pixels; this is not a decompression bomb!
Image.MAX_IMAGE_PIXELS = 10000**2

# %%
# Load the whole rooftop dataset
path = "../data/solkat/SOLKAT_DACH.gpkg"
gdf = gpd.read_file(
    path,
    layer="SOLKAT_CH_DACH",
    columns=[],
    engine="pyogrio",
    use_arrow=True,
)

# Simplify as points
centroids = gdf.centroid

# We will slice tiles into 10x10 sub-chunks (i.e. 100x100 meters)
gdf["i"] = (centroids.x / 1000).astype(int)
gdf["j"] = (centroids.y / 1000).astype(int)
gdf["u"] = (centroids.x / 100).astype(int) % 10
gdf["v"] = (centroids.y / 100).astype(int) % 10
gdf
# Out:
#                                                    geometry     i     j  u  v
# 0         MULTIPOLYGON (((2676475.451 1254000.615, 26764...  2676  1253  4  9
# 1         MULTIPOLYGON (((2676475.043 1253999.79, 267647...  2676  1254  4  0
# 2         MULTIPOLYGON (((2676475.043 1253999.79, 267646...  2676  1254  4  0
# 3         MULTIPOLYGON (((2676552.815 1253992.39, 267655...  2676  1253  5  9
# 4         MULTIPOLYGON (((2676556.556 1254000.741, 26765...  2676  1253  5  9
# ...                                                     ...   ...   ... .. ..
# 10071750  MULTIPOLYGON (((2514423.645 1172206.735, 25143...  2514  1172  4  2
# 10071751  MULTIPOLYGON (((2514398.35 1172208.981, 251439...  2514  1172  3  2
# 10071752  MULTIPOLYGON (((2513394.318 1172545.786, 25133...  2513  1172  3  5
# 10071753  MULTIPOLYGON (((2513395.31 1172544.195, 251339...  2513  1172  3  5
# 10071754  MULTIPOLYGON (((2513651.394 1172575.89, 251364...  2513  1172  6  5
#
# [10071755 rows x 5 columns]

# %%
# Assuming some images have been downloaded
input_folder = "../data/swissimage/"
input_df = pd.DataFrame()
input_df["path"] = [os.path.join(input_folder, name) for name in os.listdir(input_folder) if name.endswith(".tif")]
ij_df = input_df["path"].str.extract(r"swissimage-dop10_(?P<year>\d+)_(?P<i>\d+)-(?P<j>\d+)").astype(int)
input_df["year"] = ij_df["year"]
input_df["i"] = ij_df["i"]
input_df["j"] = ij_df["j"]
input_df
# Out:
#                                                  path  year     i     j
# 0   ../data/swissimage/swissimage-dop10_2021_2709-...  2021  2709  1111
# 1   ../data/swissimage/swissimage-dop10_2022_2706-...  2022  2706  1214
# 2   ../data/swissimage/swissimage-dop10_2023_2500-...  2023  2500  1118
# 3   ../data/swissimage/swissimage-dop10_2023_2501-...  2023  2501  1119
# 4   ../data/swissimage/swissimage-dop10_2023_2532-...  2023  2532  1152
# 5   ../data/swissimage/swissimage-dop10_2022_2763-...  2022  2763  1170
# 6   ../data/swissimage/swissimage-dop10_2023_2555-...  2023  2555  1163
# 7   ../data/swissimage/swissimage-dop10_2023_2501-...  2023  2501  1118
# 8   ../data/swissimage/swissimage-dop10_2023_2533-...  2023  2533  1152
# 9   ../data/swissimage/swissimage-dop10_2023_2500-...  2023  2500  1119
# 10  ../data/swissimage/swissimage-dop10_2023_2553-...  2023  2553  1147
# 11  ../data/swissimage/swissimage-dop10_2023_2498-...  2023  2498  1119
# 12  ../data/swissimage/swissimage-dop10_2023_2497-...  2023  2497  1120
# 13  ../data/swissimage/swissimage-dop10_2022_2747-...  2022  2747  1261
# 14  ../data/swissimage/swissimage-dop10_2023_2499-...  2023  2499  1118
# 15  ../data/swissimage/swissimage-dop10_2023_2502-...  2023  2502  1118
# 16  ../data/swissimage/swissimage-dop10_2022_2711-...  2022  2711  1220
# 17  ../data/swissimage/swissimage-dop10_2021_2582-...  2021  2582  1212
# 18  ../data/swissimage/swissimage-dop10_2023_2499-...  2023  2499  1119
# 19  ../data/swissimage/swissimage-dop10_2022_2682-...  2022  2682  1241
# 20  ../data/swissimage/swissimage-dop10_2022_2696-...  2022  2696  1226
# 21  ../data/swissimage/swissimage-dop10_2023_2498-...  2023  2498  1118
# 22  ../data/swissimage/swissimage-dop10_2021_2722-...  2021  2722  1143
# 23  ../data/swissimage/swissimage-dop10_2023_2555-...  2023  2555  1168
# 24  ../data/swissimage/swissimage-dop10_2023_2497-...  2023  2497  1117
# 25  ../data/swissimage/swissimage-dop10_2023_2502-...  2023  2502  1119
# 26  ../data/swissimage/swissimage-dop10_2024_2577-...  2024  2577  1218
# 27  ../data/swissimage/swissimage-dop10_2021_2643-...  2021  2643  1265
# 28  ../data/swissimage/swissimage-dop10_2023_2500-...  2023  2500  1117
# 29  ../data/swissimage/swissimage-dop10_2022_2700-...  2022  2700  1232
# 30  ../data/swissimage/swissimage-dop10_2023_2501-...  2023  2501  1120
# 31  ../data/swissimage/swissimage-dop10_2021_2629-...  2021  2629  1181
# 32  ../data/swissimage/swissimage-dop10_2023_2554-...  2023  2554  1149
# 33  ../data/swissimage/swissimage-dop10_2021_2646-...  2021  2646  1255
# 34  ../data/swissimage/swissimage-dop10_2023_2501-...  2023  2501  1117
# 35  ../data/swissimage/swissimage-dop10_2023_2564-...  2023  2564  1181
# 36  ../data/swissimage/swissimage-dop10_2021_2650-...  2021  2650  1208
# 37  ../data/swissimage/swissimage-dop10_2023_2500-...  2023  2500  1120
# 38  ../data/swissimage/swissimage-dop10_2023_2582-...  2023  2582  1202
# 39  ../data/swissimage/swissimage-dop10_2023_2498-...  2023  2498  1120
# 40  ../data/swissimage/swissimage-dop10_2023_2497-...  2023  2497  1119
# 41  ../data/swissimage/swissimage-dop10_2021_2692-...  2021  2692  1189
# 42  ../data/swissimage/swissimage-dop10_2023_2502-...  2023  2502  1117
# 43  ../data/swissimage/swissimage-dop10_2023_2499-...  2023  2499  1117
# 44  ../data/swissimage/swissimage-dop10_2024_2631-...  2024  2631  1242
# 45  ../data/swissimage/swissimage-dop10_2022_2712-...  2022  2712  1225
# 46  ../data/swissimage/swissimage-dop10_2023_2532-...  2023  2532  1151
# 47  ../data/swissimage/swissimage-dop10_2023_2564-...  2023  2564  1173
# 48  ../data/swissimage/swissimage-dop10_2023_2554-...  2023  2554  1151
# 49  ../data/swissimage/swissimage-dop10_2024_2616-...  2024  2616  1269
# 50  ../data/swissimage/swissimage-dop10_2023_2553-...  2023  2553  1148
# 51  ../data/swissimage/swissimage-dop10_2022_2725-...  2022  2725  1269
# 52  ../data/swissimage/swissimage-dop10_2023_2499-...  2023  2499  1120
# 53  ../data/swissimage/swissimage-dop10_2021_2627-...  2021  2627  1264
# 54  ../data/swissimage/swissimage-dop10_2023_2497-...  2023  2497  1118
# 55  ../data/swissimage/swissimage-dop10_2023_2498-...  2023  2498  1117
# 56  ../data/swissimage/swissimage-dop10_2023_2502-...  2023  2502  1120

# %%
# Generate samples
output_folder = "../data/sample/"
num_patch_per_tile = 10
for _, row in tqdm(input_df.iterrows(), total=len(input_df)):
    sub_gdf = gdf[(gdf["i"] == row["i"]) & (gdf["j"] == row["j"])]

    # Load full tile
    image = Image.open(row["path"])
    assert image.mode == "RGB"
    assert image.size == (10000, 10000)
    image.load()

    # Select chunk coordinates
    # Note: we only take the most "populated" chunks in each tile
    uvs = sub_gdf[["u", "v"]].value_counts().iloc[:num_patch_per_tile].index

    # Generate chunks
    for u, v in uvs:
        sub_name = f"swissimage-dop10_{row['year']}_{row['i']}.{u}-{row['j']}.{v}.jpg"
        sub_path = os.path.join(output_folder, sub_name)
        sub_image = image.crop((u * 1000, (10 - v - 1) * 1000, (u + 1) * 1000, (10 - v) * 1000))
        sub_image.save(sub_path)
# Out:
# 100%|██████████| 57/57 [00:35<00:00,  1.62it/s]
